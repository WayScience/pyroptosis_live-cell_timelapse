# %%
import argparse
import logging
import os
import pathlib
import pprint
import shutil

# Configure logging FIRST, before any other imports
logging.basicConfig(
    filename="tracking.log",
    level=logging.WARNING,  # Changed from DEBUG to WARNING
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
)
# Suppress ultrack logging completely
logging.getLogger("ultrack").setLevel(logging.ERROR)
logging.getLogger("ultrack.utils").setLevel(logging.ERROR)
logging.getLogger("ultrack.utils.cuda").setLevel(logging.ERROR)
logging.getLogger("ultrack.utils.edge").setLevel(logging.ERROR)

import json
from pathlib import Path

import matplotlib.pyplot as plt
import natsort
import numpy as np
import optuna
import pandas as pd
import seaborn as sns
import tifffile
import torch
from PIL import Image
from rich.pretty import pprint
from ultrack import (
    MainConfig,
    link,
    segment,
    solve,
    to_tracks_layer,
    track,
    tracks_to_zarr,
)
from ultrack.config import MainConfig
from ultrack.imgproc import detect_foreground, robust_invert
from ultrack.tracks import close_tracks_gaps
from ultrack.utils import estimate_parameters_from_labels, labels_to_contours
from ultrack.utils.array import array_apply, create_zarr

os.environ["OMP_NUM_THREADS"] = "8"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import logging

logging.getLogger("ultrack").setLevel(logging.INFO)

from timelapse_utils.file_utils.notebook_init_utils import (
    bandicoot_check,
    init_notebook,
)

root_dir, in_notebook = init_notebook()
if in_notebook:
    import tqdm.notebook as tqdm
else:
    import tqdm

# %%
# def clear_gpu_memory():
#     """
#     A little function to clear gpu memory
#     """

#     torch.cuda.empty_cache()


# clear_gpu_memory()

# begin time, CPU memory peak usage and GPU memory peak usage tracking
import time
import tracemalloc

# import pynvml

# pynvml.nvmlInit()

start_time = time.time()
tracemalloc.start()
# handle = pynvml.nvmlDeviceGetHandleByIndex(0)  # Assuming you want to track GPU 0

# %%
if not in_notebook:
    print("Running as script")
    # set up arg parser
    parser = argparse.ArgumentParser(description="Segment the nuclei of a tiff image")

    parser.add_argument(
        "--well_fov",
        type=str,
        help="Path to the input directory containing the tiff images",
    )
    parser.add_argument(
        "--generate_gif",
        action="store_true",
        help="Whether to generate a gif of the tracks",
    )

    parser.add_argument(
        "--plate_name",
        type=str,
        help="Name of the plate to process (e.g., 'Wave2')",
    )

    args = parser.parse_args()
    well_fov = args.well_fov
    generate_gif = args.generate_gif
    plate_name = args.plate_name
    if generate_gif:
        print("GIF generation is enabled, this may take a while...")

else:
    print("Running in a notebook")
    well_fov = "B2_1"  # example well_fov
    generate_gif = True
    plate_name = "plate_2"  # example plate name

image_base_dir = bandicoot_check(
    root_dir=root_dir,
    bandicoot_mount_path=pathlib.Path(os.path.expanduser("~/mnt/bandicoot")).resolve(),
)

raw_image_input_dir = pathlib.Path(
    image_base_dir / "processed_data" / "0.renamed_files" / plate_name / well_fov
).resolve(strict=True)

segmentation_mask_input_dir = pathlib.Path(
    image_base_dir
    / "processed_data"
    / "2.cell_segmentation_masks"
    / plate_name
    / well_fov
).resolve()

config_output_path = "../results/ultrack_config.json"
with open(config_output_path, "r") as f:
    config_dict = json.load(f)
config = MainConfig.parse_obj(config_dict)

temporary_output_dir = pathlib.Path("../tmp_output").resolve()
figures_output_dir = pathlib.Path("../figures").resolve()
results_output_dir = pathlib.Path("../results").resolve()
temporary_output_dir.mkdir(exist_ok=True)
figures_output_dir.mkdir(exist_ok=True)
results_output_dir.mkdir(exist_ok=True)
config = MainConfig()
pprint(config)
# Out:
# Running in a notebook
# MainConfig(
# │   data_config=DataConfig(
# │   │   n_workers=1,
# │   │   working_dir=PosixPath('.'),
# │   │   database='sqlite',
# │   │   address=None,
# │   │   in_memory_db_id=0
# │   ),
# │   segmentation_config=SegmentationConfig(
# │   │   min_area=100,
# │   │   max_area=1000000,
# │   │   n_workers=1,
# │   │   min_frontier=0.0,
# │   │   threshold=0.5,
# │   │   max_noise=0.0,
# │   │   random_seed='frame',
# │   │   ws_hierarchy=<function watershed_hierarchy_by_area at 0x7ff3dad596c0>,
# │   │   anisotropy_penalization=0.0
# │   ),
# │   linking_config=LinkingConfig(
# │   │   max_distance=15.0,
# │   │   n_workers=1,
# │   │   max_neighbors=5,
# │   │   distance_weight=0.0,
# │   │   z_score_threshold=5.0
# │   ),
# │   tracking_config=TrackingConfig(
# │   │   solver_name='',
# │   │   appear_weight=-0.001,
# │   │   disappear_weight=-0.001,
# │   │   division_weight=-0.001,
# │   │   image_border_size=None,
# │   │   n_threads=-1,
# │   │   window_size=None,
# │   │   overlap_size=1,
# │   │   solution_gap=0.001,
# │   │   time_limit=36000,
# │   │   method=0,
# │   │   link_function='power',
# │   │   power=4,
# │   │   bias=-0.0,
# │   │   dismiss_weight_guess=None,
# │   │   include_weight_guess=None
# │   )
# )

# %%
file_extensions = {".tif", ".tiff"}
# get all the raw image files
raw_images = list(raw_image_input_dir.glob("*"))
raw_images = [f for f in raw_images if f.suffix in file_extensions]
raw_images = sorted(raw_images)

# get all the segmentation mask files
segmentation_masks = list(segmentation_mask_input_dir.glob("*"))
segmentation_masks = [f for f in segmentation_masks if f.suffix in file_extensions]
segmentation_masks = sorted(segmentation_masks)


nuclei_files = [f for f in raw_images if "C4" in f.name.split("_")[3]]
mask_files = [f for f in segmentation_masks if "nuclei" in f.name]

nuclei_files = natsort.natsorted(nuclei_files)
mask_files = natsort.natsorted(mask_files)

print(f"Found {len(mask_files)} segmentation mask files in the input directory")
print(f"Found {len(nuclei_files)} nuclei files in the input directory")
# Out:
# Found 288 segmentation mask files in the input directory
# Found 288 nuclei files in the input directory

# %%
# read in the masks and create labels
masks = []
for tiff_file in mask_files[:5]:
    img = tifffile.imread(tiff_file)
    masks.append(img)

masks = np.array(masks)

nuclei = []
for tiff_file in nuclei_files[:5]:
    img = tifffile.imread(tiff_file)
    nuclei.append(img)
nuclei = np.array(nuclei)

# %%
image_dims = nuclei[0].shape

# %%
detections = np.zeros((len(masks), image_dims[0], image_dims[1]), dtype=np.uint16)
edges = np.zeros((len(masks), image_dims[0], image_dims[1]), dtype=np.uint16)
for frame_index, frame in tqdm.tqdm(
    enumerate(masks), total=len(masks), desc="Processing frames"
):
    detections[frame_index, :, :], edges[frame_index, :, :] = labels_to_contours(frame)
print(detections.shape, edges.shape)

# clear_gpu_memory()
# Out:
# Processing frames:   0%|          | 0/5 [00:00<?, ?it/s]
# Converting labels to contours: 100%|██████████| 2000/2000 [00:03<00:00, 539.25it/s]
# Converting labels to contours: 100%|██████████| 2000/2000 [00:03<00:00, 545.20it/s]
# Converting labels to contours: 100%|██████████| 2000/2000 [00:03<00:00, 534.96it/s]
# Converting labels to contours: 100%|██████████| 2000/2000 [00:03<00:00, 558.99it/s]
# Converting labels to contours: 100%|██████████| 2000/2000 [00:03<00:00, 556.00it/s]
# (5, 2000, 2000) (5, 2000, 2000)

# %%
params_df = estimate_parameters_from_labels(masks, is_timelapse=True)
if in_notebook:
    params_df["area"].plot(kind="hist", bins=100, title="Nuclei Area histogram")
# Out:
# Estimating params.: 100%|██████████| 5/5 [00:00<00:00,  8.66it/s]

# %%
config.segmentation_config.min_area = 50
config.segmentation_config.max_area = 5000
config.segmentation_config.n_workers = 1
config.segmentation_config.threshold = 0.25


config.linking_config.max_distance = 25

config.tracking_config.appear_weight = -1
config.tracking_config.disappear_weight = -1
config.tracking_config.division_weight = -0.1
config.tracking_config.power = 4
config.tracking_config.bias = -0.001
config.tracking_config.solution_gap = 0.0

# %%
track(
    foreground=detections,
    edges=edges,
    config=config,
    overwrite=True,
)
# Out:
# Adding nodes to database: 100%|██████████| 5/5 [00:41<00:00,  8.33s/it]
# Linking nodes.: 100%|██████████| 4/4 [00:03<00:00,  1.27it/s]
# Using Coin-OR Branch and Cut solver
# Solving ILP batch 0
# Constructing ILP ...
# Solving ILP ...
# Welcome to the CBC MILP Solver
# Version: devel
# Build Date: Mar 23 2026
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 918 (-4577) rows, 1596 (-5995) columns and 2584 (-10925) elements
# Clp1000I sum of infeasibilities 0.00145324 - average 1.58304e-06, 979 fixed columns
# Coin0506I Presolve 47 (-871) rows, 71 (-1525) columns and 125 (-2459) elements
# Clp0029I End of values pass after 69 iterations
# Clp0000I Optimal - objective value -2.5756731
# Clp0000I Optimal - objective value -2.5756731
# Coin0511I After Postsolve, objective -2.5756731, infeasibilities - dual 121.92042 (136), primal 0 (0)
# Coin0512I Presolved model was optimal, full model needs cleaning up
# Clp0014I Perturbing problem by 0.001% of 1.0000001 - largest nonzero change 2.8691903e-05 ( 0.0014345952%) - largest zero change 2.9936918e-05
# Clp0000I Optimal - objective value 0.42432695
# Clp0000I Optimal - objective value 0.42432695
# Coin0511I After Postsolve, objective 0.42432695, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 0.4243269498 - 0 iterations time 0.042, Presolve 0.01, Idiot 0.03
#
# Starting MIP optimization
# Cbc0045I Nauty did not find any useful orbits in time 0.013453
# Cbc0038I Initial state - 13 integers unsatisfied sum - 4.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 0.125367 iterations 177
# Cbc0038I Solution found of 0.1253673130578
# Cbc0038I Before mini branch and bound, 1858 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1344 rows 1873 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I Round again with cutoff of 0.155353
# Cbc0038I Reduced cost fixing fixed 1067 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.54059 (6) obj. 0.155353 iterations 120
# Cbc0038I Pass   3: suminf.    0.54059 (6) obj. 0.155353 iterations 18
# Cbc0038I Pass   4: suminf.    1.38457 (5) obj. 0.155353 iterations 48
# Cbc0038I Pass   5: suminf.    1.38457 (5) obj. 0.155353 iterations 0
# Cbc0038I Pass   6: suminf.    2.00000 (5) obj. 0.155353 iterations 17
# Cbc0038I Pass   7: suminf.    2.00000 (5) obj. 0.291774 iterations 2
# Cbc0038I Pass   8: suminf.    2.29096 (7) obj. 0.155353 iterations 52
# Cbc0038I Pass   9: suminf.    2.00000 (5) obj. 0.291774 iterations 39
# Cbc0038I Pass  10: suminf.    2.29972 (7) obj. 0.155353 iterations 51
# Cbc0038I Pass  11: suminf.    2.29020 (7) obj. 0.155353 iterations 38
# Cbc0038I Pass  12: suminf.    2.33147 (7) obj. 0.155353 iterations 40
# Cbc0038I Pass  13: suminf.    2.39549 (7) obj. 0.155353 iterations 32
# Cbc0038I Pass  14: suminf.    2.32740 (7) obj. 0.155353 iterations 35
# Cbc0038I Pass  15: suminf.    2.56058 (9) obj. 0.155353 iterations 36
# Cbc0038I Pass  16: suminf.    2.29098 (7) obj. 0.155353 iterations 31
# Cbc0038I Pass  17: suminf.    2.30913 (7) obj. 0.155353 iterations 27
# Cbc0038I Pass  18: suminf.    2.82071 (7) obj. 0.155353 iterations 38
# Cbc0038I Pass  19: suminf.    2.63602 (7) obj. 0.155353 iterations 21
# Cbc0038I Pass  20: suminf.    3.00000 (7) obj. 0.155353 iterations 50
# Cbc0038I Pass  21: suminf.    2.82071 (7) obj. 0.155353 iterations 6
# Cbc0038I Pass  22: suminf.    2.82071 (7) obj. 0.155353 iterations 32
# Cbc0038I Pass  23: suminf.    2.63602 (7) obj. 0.155353 iterations 1
# Cbc0038I Pass  24: suminf.    1.38457 (5) obj. 0.155353 iterations 1
# Cbc0038I Pass  25: suminf.    1.38457 (5) obj. 0.155353 iterations 0
# Cbc0038I Pass  26: suminf.    2.00000 (5) obj. 0.155353 iterations 50
# Cbc0038I Pass  27: suminf.    2.00000 (5) obj. 0.291774 iterations 2
# Cbc0038I Pass  28: suminf.    2.30733 (7) obj. 0.155353 iterations 55
# Cbc0038I Pass  29: suminf.    2.00000 (5) obj. 0.291774 iterations 69
# Cbc0038I Pass  30: suminf.    1.38457 (5) obj. 0.155353 iterations 55
# Cbc0038I Pass  31: suminf.    2.91159 (10) obj. 0.155353 iterations 28
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1828 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.14 seconds)
# Cbc0038I After 0.15 seconds - Feasibility pump exiting with objective of 0.1253673130578 - took 0.14 seconds
# Cbc0012I Integer solution of 0.1253673130578 found by feasibility pump after 0 iterations and 0 nodes (0.15 seconds)
# Cbc0038I Full problem 1344 rows 1873 columns, reduced to 0 rows 0 columns
# Cbc0051I Starting cut generation at root node
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 0.42432695 to 0.12536731 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 33 row cuts average 2.0 elements, 38 column cuts (38 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0030I Thread 0 used 0 times,  waiting to start 0.1820507, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 1 used 0 times,  waiting to start 0.18074608, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 2 used 0 times,  waiting to start 0.17835832, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 3 used 0 times,  waiting to start 0.17620969, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 4 used 0 times,  waiting to start 0.17398524, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 5 used 0 times,  waiting to start 0.17172027, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 6 used 0 times,  waiting to start 0.16884923, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 7 used 0 times,  waiting to start 0.16475058, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 8 used 0 times,  waiting to start 0.16065025, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 9 used 0 times,  waiting to start 0.15667939, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 10 used 0 times,  waiting to start 0.15285587, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 11 used 0 times,  waiting to start 0.14890122, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 12 used 0 times,  waiting to start 0.14504361, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 13 used 0 times,  waiting to start 0.14105439, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 14 used 0 times,  waiting to start 0.13729692, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 15 used 0 times,  waiting to start 0.13325191, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 16 used 0 times,  waiting to start 0.129426, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 17 used 0 times,  waiting to start 0.12544775, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 18 used 0 times,  waiting to start 0.12137675, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 19 used 0 times,  waiting to start 0.11671185, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 20 used 0 times,  waiting to start 0.11262441, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 21 used 0 times,  waiting to start 0.10835552, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 22 used 0 times,  waiting to start 0.10396147, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 23 used 0 times,  waiting to start 0.09992218, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 24 used 0 times,  waiting to start 0.096030474, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 25 used 0 times,  waiting to start 0.091961861, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 26 used 0 times,  waiting to start 0.087406158, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 27 used 0 times,  waiting to start 0.083399534, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 28 used 0 times,  waiting to start 0.079226732, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 29 used 0 times,  waiting to start 0.075053692, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 30 used 0 times,  waiting to start 0.070718288, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 31 used 0 times,  waiting to start 0.066879988, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 32 used 0 times,  waiting to start 0.062904596, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 33 used 0 times,  waiting to start 0.05901742, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 34 used 0 times,  waiting to start 0.054885626, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 35 used 0 times,  waiting to start 0.050982714, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 36 used 0 times,  waiting to start 0.047147036, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 37 used 0 times,  waiting to start 0.042807817, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 38 used 0 times,  waiting to start 0.038963556, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 39 used 0 times,  waiting to start 0.035114527, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 40 used 0 times,  waiting to start 0.031167746, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 41 used 0 times,  waiting to start 0.027182817, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 42 used 0 times,  waiting to start 0.023148775, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 43 used 0 times,  waiting to start 0.019132137, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 44 used 0 times,  waiting to start 0.015115738, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 45 used 0 times,  waiting to start 0.011263609, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 46 used 0 times,  waiting to start 0.0072343349, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 47 used 0 times,  waiting to start 0.0033321381, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Main thread 0 waiting for threads,  1 locks, 1.9073486e-06 locked, 4.7683716e-07 waiting for locks
# Cbc0011I Exiting as integer gap of 0 less than 1e-10 or 0%
# Cbc0001I Search completed - best objective 0.1253673130577677, took 3 iterations and 0 nodes (0.39 seconds)
# Cbc0035I Maximum depth 0, 1067 variables fixed on reduced cost
# Saving solution ...
# Done!

# %%
tracks_df, graph = to_tracks_layer(config)
# tracks_df = close_tracks_gaps(
#     tracks_df=tracks_df,
#     max_gap=2,
#     max_radius=50,
#     spatial_columns=["y", "x"],
# )

# %%
labels = tracks_to_zarr(config, tracks_df)
# save the tracks as parquet
tracks_df.to_parquet(
    f"{results_output_dir}/{well_fov}_tracks.parquet",
)
print(tracks_df["track_id"].nunique())
print(f"Found {tracks_df['track_id'].nunique()} unique tracks in the dataset.")
tracks_df.head()
# Out:
# Exporting segmentation masks: 100%|██████████| 5/5 [00:00<00:00, 56.13it/s]
# 1
# Found 1 unique tracks in the dataset.
#          track_id  t      y       x       id  parent_track_id  parent_id
# id
# 1000152         1  0  775.0  1977.0  1000152               -1         -1
# 2000145         1  1  765.0  1965.0  2000145               -1    1000152
# 3000142         1  2  757.0  1987.0  3000142               -1    2000145
# 4000133         1  3  741.0  1971.0  4000133               -1    3000142
# 5000138         1  4  740.0  1956.0  5000138               -1    4000133

# %%
if in_notebook:
    # get the number of unique objects per frame and the unique tracks per frame
    unique_objects_per_frame_dict = {
        "frame": [],
        "n_unique_objects": [],
    }
    for frame_number, frame_image in enumerate(masks):
        unique_objects_per_frame_dict["frame"].append(frame_number)
        unique_objects_per_frame_dict["n_unique_objects"].append(
            np.unique(frame_image).size
        )
    unique_objects_per_frame_df = pd.DataFrame(unique_objects_per_frame_dict)

    # plot the number of unique objects per frame and the unique tracks per frame
    objects_per_frame = tracks_df.groupby("t")["track_id"].nunique()
    plt.figure(figsize=(10, 6))
    # plot the first line (unique objects per frame)
    plt.plot(
        unique_objects_per_frame_df["frame"],
        unique_objects_per_frame_df["n_unique_objects"],
        label="Unique Objects",
    )
    # plot the second line (unique tracks per frame)
    plt.plot(objects_per_frame.index, objects_per_frame.values, label="Unique Tracks")
    plt.title("Number of Unique Objects and Tracks per Frame")
    plt.xlabel("Frame")
    plt.ylabel("Number of Unique Items")
    plt.legend()
    plt.savefig(
        f"{figures_output_dir}/{well_fov}_unique_objects_and_tracks_per_frame.png"
    )
    plt.show()

# %%
if generate_gif:
    tracks_df.reset_index(drop=True, inplace=True)
    cum_tracks_df = tracks_df.copy()
    # zero out the track_df for plotting
    cum_tracks_df = cum_tracks_df.loc[cum_tracks_df["t"] == -1]
    for frame_index, _ in enumerate(nuclei):
        tmp_df = tracks_df.loc[tracks_df["t"] == frame_index]
        cum_tracks_df = pd.concat([cum_tracks_df, tmp_df])
        plt.figure(figsize=(6, 3))
        plt.subplot(121)
        plt.imshow(detections[frame_index, :, :], cmap="gray")
        plt.title("Detections")
        plt.axis("off")

        plt.subplot(122)
        sns.lineplot(
            data=cum_tracks_df,
            x="x",
            y="y",
            hue="track_id",
            legend=False,
            palette="Spectral",
            linewidth=0.8,
            alpha=0.8,
        )
        plt.imshow(detections[frame_index, :, :], cmap="gray", alpha=0.3)
        plt.title(f"Frame {frame_index}")
        plt.axis("off")

        plt.tight_layout()
        plt.savefig(f"{temporary_output_dir}/tracks_{frame_index}.png")
        plt.close()
    # load each image
    files = [f for f in temporary_output_dir.glob("*.png")]
    files = sorted(files, key=lambda x: int(x.stem.split("_")[1]))
    frames = [Image.open(f) for f in files]
    fig_path = figures_output_dir / f"{well_fov}_tracks.gif"
    # plot the line of each track in matplotlib over a gif
    # get the tracks
    # save the frames as a gif
    frames[0].save(
        fig_path, save_all=True, append_images=frames[1:], duration=750, loop=0
    )

# %%
# # clean up tracking files
# # remove temporary_output_dir
# shutil.rmtree(temporary_output_dir)

# track_db_path = pathlib.Path("data.db").resolve()
# metadata_toml_path = pathlib.Path("metadata.toml").resolve()
# if track_db_path.exists():
#     track_db_path.unlink()
# if metadata_toml_path.exists():
#     metadata_toml_path.unlink()

# %%
# clear_gpu_memory()

# %%
end_time = time.time()
current, peak = tracemalloc.get_traced_memory()
# mem_info = pynvml.nvmlDeviceGetMemoryInfo(handle)
print(f"Time taken for tracking: {end_time - start_time:.2f} seconds")
print(f"Peak memory used: {peak / (1024**3):.2f} GB")
# print(f"GPU Memory used: {mem_info.used / (1024**3):.2f} GB")
# Out:
# Time taken for tracking: 93.34 seconds
# Peak memory used: 0.52 GB
